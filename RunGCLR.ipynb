# %%
#Install Library
# !pip install opencv-python
# !pip install pytorch-lightning
# !pip install avalanche-lib
# !pip install torch
# !pip install torchvision
# !pip install albumentations
# !pip install tqdm
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# !pwd
# Out:
# /workspace/yogiek/gc2

# %%
import torch
import sys
sys.path.append('/workspace/yogiek/gc2/warmup')
sys.path.append('/workspace/yogiek/gc2/main')

# %%
#1st Training with EWC
# !python "warmup/main/train1_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|███████████████████████████████████████████| 18/18 [00:08<00:00,  2.04it/s]
# train    - loss:0.8985, accuracy:0.6978
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  3.67it/s]
# val      - loss:0.8120, accuracy:0.7500
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|███████████████████████████████████████████| 18/18 [00:04<00:00,  4.16it/s]
# train    - loss:0.6643, accuracy:0.9029
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# val      - loss:0.8823, accuracy:0.6346
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|███████████████████████████████████████████| 18/18 [00:04<00:00,  4.01it/s]
# train    - loss:0.6111, accuracy:0.9451
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  3.53it/s]
# ...

# %%
#1st Generalization with EWC
# !python "main/main/train1_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  6.57it/s]
# running loss = 355.8079614639282
# val      - loss:2.2808, accuracy:0.6346
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  6.41it/s]
# running loss = 370.95674419403076
# val      - loss:2.3779, accuracy:0.6090
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  6.46it/s]
# running loss = 353.9092426300049
# val      - loss:2.2686, accuracy:0.6346
# epoch 4/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  6.16it/s]
# running loss = 324.6562614440918
# val      - loss:2.0811, accuracy:0.6538
# ...

# %%
#2nd Training with EWC
# !python "warmup/main/train2_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████| 196/196 [00:21<00:00,  9.09it/s]
# train    - loss:0.9698, accuracy:0.9494
# 100%|███████████████████████████████████████████| 56/56 [00:09<00:00,  6.16it/s]
# val      - loss:0.9267, accuracy:0.9782
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████| 196/196 [00:21<00:00,  9.32it/s]
# train    - loss:0.9250, accuracy:0.9813
# 100%|███████████████████████████████████████████| 56/56 [00:04<00:00, 13.23it/s]
# val      - loss:0.9818, accuracy:0.9210
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████| 196/196 [00:21<00:00,  9.31it/s]
# train    - loss:0.9193, accuracy:0.9872
# 100%|███████████████████████████████████████████| 56/56 [00:04<00:00, 13.37it/s]
# ...

# %%
#2nd Generalization with EWC
# !python "main/main/train2_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|███████████████████████████████████████████| 56/56 [00:01<00:00, 37.68it/s]
# running loss = 1344.5075517037444
# val      - loss:0.7532, accuracy:0.9154
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|███████████████████████████████████████████| 56/56 [00:01<00:00, 35.91it/s]
# running loss = 948.1372075671845
# val      - loss:0.5312, accuracy:0.9367
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|███████████████████████████████████████████| 56/56 [00:01<00:00, 36.06it/s]
# running loss = 815.9846237745396
# val      - loss:0.4571, accuracy:0.9496
# epoch 4/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|███████████████████████████████████████████| 56/56 [00:01<00:00, 37.19it/s]
# running loss = 517.9051344266204
# val      - loss:0.2901, accuracy:0.9630
# ...

# %%
#3rd Training with EWC
# !python "warmup/main/train3_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████| 351/351 [00:38<00:00,  9.13it/s]
# train    - loss:1.3786, accuracy:0.9065
# 100%|█████████████████████████████████████████| 101/101 [00:08<00:00, 12.48it/s]
# val      - loss:1.3474, accuracy:0.9276
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████| 351/351 [00:37<00:00,  9.30it/s]
# train    - loss:1.3163, accuracy:0.9604
# 100%|█████████████████████████████████████████| 101/101 [00:08<00:00, 12.60it/s]
# val      - loss:1.2970, accuracy:0.9772
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████| 351/351 [00:37<00:00,  9.24it/s]
# train    - loss:1.3063, accuracy:0.9691
# 100%|█████████████████████████████████████████| 101/101 [00:07<00:00, 12.69it/s]
# ...

# %%
#3rd Generalization with EWC
# !python "main/main/train3_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 41.15it/s]
# running loss = 2178.702653947587
# val      - loss:0.6798, accuracy:0.9317
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 38.86it/s]
# running loss = 1181.883509209832
# val      - loss:0.3688, accuracy:0.9626
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 40.27it/s]
# running loss = 715.6373135132748
# val      - loss:0.2233, accuracy:0.9744
# epoch 4/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 40.93it/s]
# running loss = 393.41283474865656
# val      - loss:0.1227, accuracy:0.9819
# ...

# %%
#4th Training with EWC
# !python "warmup/main/train4_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  4.49it/s]
# train    - loss:1.0332, accuracy:0.5071
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  8.75it/s]
# val      - loss:1.0499, accuracy:0.3750
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  7.75it/s]
# train    - loss:0.7928, accuracy:0.8571
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  9.43it/s]
# val      - loss:1.0112, accuracy:0.5000
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  7.50it/s]
# train    - loss:0.6625, accuracy:0.9714
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  9.51it/s]
# ...

# %%
#4th Generalization with EWC
# !python "main/main/train4_ewc.py"
# Out:
# Seed set to 23
#
# Start Training ...
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# epoch 1/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  8.50it/s]
# running loss = 103.58279037475586
# val      - loss:2.5896, accuracy:0.6500
# epoch 2/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 10.20it/s]
# running loss = 98.59223937988281
# val      - loss:2.4648, accuracy:0.6500
# epoch 3/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 10.37it/s]
# running loss = 95.44239044189453
# val      - loss:2.3861, accuracy:0.6500
# epoch 4/500
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  9.90it/s]
# running loss = 94.44320678710938
# val      - loss:2.3611, accuracy:0.6000
# ...

# %%
#Inference dataset 1 with EWC
import os
import torch
import numpy as np
from torchvision import transforms
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from warmup.models import fcn_resnet50

# single inference
def infer(model, image_path, device, infer_type):
    model.eval()  # Set model ke mode evaluasi
    with torch.no_grad():
        # Load dan preprocess gambar
        image = Image.open(image_path).convert("RGB")
        preprocess = transforms.Compose([
            transforms.Resize((224, 224)),  # Sesuaikan ukuran gambar sesuai dengan model
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalisasi sesuai model
        ])
        input_tensor = preprocess(image).unsqueeze(0).to(device)  # Tambahkan dimensi batch dan pindah ke device

        # Lakukan inferensi
        output = model(input_tensor)

        if infer_type == 'warmup':
            probabilities = torch.softmax(output, dim=1)  # Mengubah output menjadi probabilitas
            _, predicted = torch.max(probabilities, 1)  # Ambil kelas dengan probabilitas tertinggi
        else:
            predicted = torch.argmax(output.mean(dim=[2, 3]), dim=1)  # Menggunakan rata-rata spatial untuk tipe lain

        return predicted.item()  # Kembalikan label kelas

# Fungsi untuk otomasi testing
def automate_testing(model_path, image_dir, num_classes, device, infer_type):
    """
    Automates the testing process for a classification model.

    Args:
        model_path (str): Path to the trained model file.
        image_dir (str): Directory containing test images.
        num_classes (int): Number of classes in the classification problem.
        device (torch.device): Device to run the model on (CPU or GPU).
    """
    try:
        # Load the model
        model = torch.load(model_path, map_location=device)
        model.to(device)  # Memindahkan model ke device
        model.eval()

        # Initialize lists to store predictions and true labels
        predicted_labels = []
        true_labels = []

        # Iterate through the test images
        for cls in os.listdir(image_dir):
            cls_path = os.path.join(image_dir, cls)
            if not os.path.isdir(cls_path):
                continue
            for img in os.listdir(cls_path):
                image_path = os.path.join(cls_path, img)
                if image_path.endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                    predicted_label = infer(model, image_path, device, infer_type)
                    predicted_labels.append(predicted_label)
                    true_labels.append(int(cls))

        # Create the confusion matrix
        cm = confusion_matrix(true_labels, predicted_labels, labels=list(range(num_classes)))

        # Plot the confusion matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                    xticklabels=list(range(num_classes)),
                    yticklabels=list(range(num_classes)))
        plt.xlabel("Predicted Label")
        plt.ylabel("True Label")
        plt.title("Confusion Matrix")
        plt.show()

        # Compute and print metrics
        accuracy = accuracy_score(true_labels, predicted_labels)
        precision = precision_score(true_labels, predicted_labels, average='weighted')
        recall = recall_score(true_labels, predicted_labels, average='weighted')
        f1 = f1_score(true_labels, predicted_labels, average='weighted')

        print("Accuracy: {:.2f}%".format(accuracy * 100))
        print("Precision: {:.2f}%".format(precision * 100))
        print("Recall: {:.2f}%".format(recall * 100))
        print("F1 Score: {:.2f}%".format(f1 * 100))

        # Generate and print classification report
        target_names = [str(i) for i in range(num_classes)]
        print("\nClassification Report:")
        print(classification_report(true_labels, predicted_labels, target_names=target_names))

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example Usage
infer_type = 'warmup'

# Define model
if infer_type == 'warmup':
    model = fcn_resnet50(num_classes=3)
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BUS_EWC_val/best.ptl'  # Warmup weight
else:
    from main.models import fcn_resnet50, fcn_3x64_gctx
    FT = torch.load('/workspace/yogiek/gc2/warmup/ckps/H-D/BUS_EWC_val/best.ptl', map_location='cpu')
    for parameter in FT.parameters():
        parameter.requires_grad = False
    model = {
        "FT": FT,
        "FS": fcn_resnet50(),
        "GS": fcn_3x64_gctx(),
    }
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BUS_EWC_val/best-all.ptl'  # OOD weight

# Test dataset 1
image_dir = '/workspace/yogiek/gc2/datasets/H-D/test/1'  # Replace with your images directory
num_classes = 3  # Replace with the number of class in your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Dataset 1")
automate_testing(weight_dir, image_dir, num_classes, device, infer_type)
# Out:
# Dataset 1
# Accuracy: 78.21%
# Precision: 78.09%
# Recall: 78.21%
# F1 Score: 77.87%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.81        13
#            1       0.79      0.84      0.81        44
#            2       0.76      0.62      0.68        21
#
#     accuracy                           0.78        78
#    macro avg       0.78      0.77      0.77        78
# weighted avg       0.78      0.78      0.78        78

# %%
#Inference dataset 2 with EWC
import os
import torch
import numpy as np
from torchvision import transforms
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from warmup.models import fcn_resnet50

# single inference
def infer(model, image_path, device, infer_type):
    model.eval()  # Set model ke mode evaluasi
    with torch.no_grad():
        # Load dan preprocess gambar
        image = Image.open(image_path).convert("RGB")
        preprocess = transforms.Compose([
            transforms.Resize((224, 224)),  # Sesuaikan ukuran gambar sesuai dengan model
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalisasi sesuai model
        ])
        input_tensor = preprocess(image).unsqueeze(0).to(device)  # Tambahkan dimensi batch dan pindah ke device

        # Lakukan inferensi
        output = model(input_tensor)

        if infer_type == 'warmup':
            probabilities = torch.softmax(output, dim=1)  # Mengubah output menjadi probabilitas
            _, predicted = torch.max(probabilities, 1)  # Ambil kelas dengan probabilitas tertinggi
        else:
            predicted = torch.argmax(output.mean(dim=[2, 3]), dim=1)  # Menggunakan rata-rata spatial untuk tipe lain

        return predicted.item()  # Kembalikan label kelas

# Fungsi untuk otomasi testing
def automate_testing(model_path, image_dir, num_classes, device, infer_type):
    """
    Automates the testing process for a classification model.

    Args:
        model_path (str): Path to the trained model file.
        image_dir (str): Directory containing test images.
        num_classes (int): Number of classes in the classification problem.
        device (torch.device): Device to run the model on (CPU or GPU).
    """
    try:
        # Load the model
        model = torch.load(model_path, map_location=device)
        model.to(device)  # Memindahkan model ke device
        model.eval()

        # Initialize lists to store predictions and true labels
        predicted_labels = []
        true_labels = []

        # Iterate through the test images
        for cls in os.listdir(image_dir):
            cls_path = os.path.join(image_dir, cls)
            if not os.path.isdir(cls_path):
                continue
            for img in os.listdir(cls_path):
                image_path = os.path.join(cls_path, img)
                if image_path.endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                    predicted_label = infer(model, image_path, device, infer_type)
                    predicted_labels.append(predicted_label)
                    true_labels.append(int(cls))

        # Create the confusion matrix
        cm = confusion_matrix(true_labels, predicted_labels, labels=list(range(num_classes)))

        # Plot the confusion matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                    xticklabels=list(range(num_classes)),
                    yticklabels=list(range(num_classes)))
        plt.xlabel("Predicted Label")
        plt.ylabel("True Label")
        plt.title("Confusion Matrix")
        plt.show()

        # Compute and print metrics
        accuracy = accuracy_score(true_labels, predicted_labels)
        precision = precision_score(true_labels, predicted_labels, average='weighted')
        recall = recall_score(true_labels, predicted_labels, average='weighted')
        f1 = f1_score(true_labels, predicted_labels, average='weighted')

        print("Accuracy: {:.2f}%".format(accuracy * 100))
        print("Precision: {:.2f}%".format(precision * 100))
        print("Recall: {:.2f}%".format(recall * 100))
        print("F1 Score: {:.2f}%".format(f1 * 100))

        # Generate and print classification report
        target_names = [str(i) for i in range(num_classes)]
        print("\nClassification Report:")
        print(classification_report(true_labels, predicted_labels, target_names=target_names))

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example Usage
infer_type = 'warmup'

# Define model
if infer_type == 'warmup':
    model = fcn_resnet50(num_classes=5)
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD1_EWC_val/best.ptl'  # Warmup weight
else:
    from main.models import fcn_resnet50, fcn_3x64_gctx
    FT = torch.load('/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD1_EWC_val/best.ptl', map_location='cpu')
    for parameter in FT.parameters():
        parameter.requires_grad = False
    model = {
        "FT": FT,
        "FS": fcn_resnet50(),
        "GS": fcn_3x64_gctx(),
    }
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD1_EWC_val/best-all.ptl'  # OOD weight

# Test dataset 2
image_dir = '/workspace/yogiek/gc2/datasets/H-D/test/2'  # Replace with your images directory
num_classes = 5  # Replace with the number of class in your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Dataset 2")
automate_testing(weight_dir, image_dir, num_classes, device, infer_type)
# Out:
# Dataset 2
# Accuracy: 99.66%
# Precision: 99.67%
# Recall: 99.66%
# F1 Score: 99.66%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       122
#            1       1.00      1.00      1.00       312
#            2       0.98      1.00      0.99        48
#            3       1.00      0.99      1.00       289
#            4       0.99      0.99      0.99       121
#
#     accuracy                           1.00       892
#    macro avg       0.99      1.00      0.99       892
# weighted avg       1.00      1.00      1.00       892

# %%
#Inference dataset 3 with EWC
import os
import torch
import numpy as np
from torchvision import transforms
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from warmup.models import fcn_resnet50

# single inference
def infer(model, image_path, device, infer_type):
    model.eval()  # Set model ke mode evaluasi
    with torch.no_grad():
        # Load dan preprocess gambar
        image = Image.open(image_path).convert("RGB")
        preprocess = transforms.Compose([
            transforms.Resize((224, 224)),  # Sesuaikan ukuran gambar sesuai dengan model
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalisasi sesuai model
        ])
        input_tensor = preprocess(image).unsqueeze(0).to(device)  # Tambahkan dimensi batch dan pindah ke device

        # Lakukan inferensi
        output = model(input_tensor)

        if infer_type == 'warmup':
            probabilities = torch.softmax(output, dim=1)  # Mengubah output menjadi probabilitas
            _, predicted = torch.max(probabilities, 1)  # Ambil kelas dengan probabilitas tertinggi
        else:
            predicted = torch.argmax(output.mean(dim=[2, 3]), dim=1)  # Menggunakan rata-rata spatial untuk tipe lain

        return predicted.item()  # Kembalikan label kelas

# Fungsi untuk otomasi testing
def automate_testing(model_path, image_dir, num_classes, device, infer_type):
    """
    Automates the testing process for a classification model.

    Args:
        model_path (str): Path to the trained model file.
        image_dir (str): Directory containing test images.
        num_classes (int): Number of classes in the classification problem.
        device (torch.device): Device to run the model on (CPU or GPU).
    """
    try:
        # Load the model
        model = torch.load(model_path, map_location=device)
        model.to(device)  # Memindahkan model ke device
        model.eval()

        # Initialize lists to store predictions and true labels
        predicted_labels = []
        true_labels = []

        # Iterate through the test images
        for cls in os.listdir(image_dir):
            cls_path = os.path.join(image_dir, cls)
            if not os.path.isdir(cls_path):
                continue
            for img in os.listdir(cls_path):
                image_path = os.path.join(cls_path, img)
                if image_path.endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                    predicted_label = infer(model, image_path, device, infer_type)
                    predicted_labels.append(predicted_label)
                    true_labels.append(int(cls))

        # Create the confusion matrix
        cm = confusion_matrix(true_labels, predicted_labels, labels=list(range(num_classes)))

        # Plot the confusion matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                    xticklabels=list(range(num_classes)),
                    yticklabels=list(range(num_classes)))
        plt.xlabel("Predicted Label")
        plt.ylabel("True Label")
        plt.title("Confusion Matrix")
        plt.show()

        # Compute and print metrics
        accuracy = accuracy_score(true_labels, predicted_labels)
        precision = precision_score(true_labels, predicted_labels, average='weighted')
        recall = recall_score(true_labels, predicted_labels, average='weighted')
        f1 = f1_score(true_labels, predicted_labels, average='weighted')

        print("Accuracy: {:.2f}%".format(accuracy * 100))
        print("Precision: {:.2f}%".format(precision * 100))
        print("Recall: {:.2f}%".format(recall * 100))
        print("F1 Score: {:.2f}%".format(f1 * 100))

        # Generate and print classification report
        target_names = [str(i) for i in range(num_classes)]
        print("\nClassification Report:")
        print(classification_report(true_labels, predicted_labels, target_names=target_names))

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example Usage
infer_type = 'warmup'

# Define model
if infer_type == 'warmup':
    model = fcn_resnet50(num_classes=8)
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD2_EWC_val/best.ptl'  # Warmup weight
else:
    from main.models import fcn_resnet50, fcn_3x64_gctx
    FT = torch.load('/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD2_EWC_val/best.ptl', map_location='cpu')
    for parameter in FT.parameters():
        parameter.requires_grad = False
    model = {
        "FT": FT,
        "FS": fcn_resnet50(),
        "GS": fcn_3x64_gctx(),
    }
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/BLOOD2_EWC_val/best-all.ptl'  # OOD weight

# Test dataset 3
image_dir = '/workspace/yogiek/gc2/datasets/H-D/test/3'  # Replace with your images directory
num_classes = 8  # Replace with the number of class in your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Dataset 3")
automate_testing(weight_dir, image_dir, num_classes, device, infer_type)
# Out:
# Dataset 3
# Accuracy: 99.44%
# Precision: 99.45%
# Recall: 99.44%
# F1 Score: 99.44%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       122
#            1       1.00      1.00      1.00       312
#            2       1.00      1.00      1.00        48
#            3       1.00      0.98      0.99       289
#            4       0.99      1.00      1.00       121
#            5       0.96      0.99      0.97       142
#            6       1.00      1.00      1.00       333
#            7       1.00      1.00      1.00       235
#
#     accuracy                           0.99      1602
#    macro avg       0.99      1.00      0.99      1602
# weighted avg       0.99      0.99      0.99      1602

# %%
#Inference dataset 4 with EWC
import os
import torch
import numpy as np
from torchvision import transforms
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from warmup.models import fcn_resnet50

# single inference
def infer(model, image_path, device, infer_type):
    model.eval()  # Set model ke mode evaluasi
    with torch.no_grad():
        # Load dan preprocess gambar
        image = Image.open(image_path).convert("RGB")
        preprocess = transforms.Compose([
            transforms.Resize((224, 224)),  # Sesuaikan ukuran gambar sesuai dengan model
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalisasi sesuai model
        ])
        input_tensor = preprocess(image).unsqueeze(0).to(device)  # Tambahkan dimensi batch dan pindah ke device

        # Lakukan inferensi
        output = model(input_tensor)

        if infer_type == 'warmup':
            probabilities = torch.softmax(output, dim=1)  # Mengubah output menjadi probabilitas
            _, predicted = torch.max(probabilities, 1)  # Ambil kelas dengan probabilitas tertinggi
        else:
            predicted = torch.argmax(output.mean(dim=[2, 3]), dim=1)  # Menggunakan rata-rata spatial untuk tipe lain

        return predicted.item()  # Kembalikan label kelas

# Fungsi untuk otomasi testing
def automate_testing(model_path, image_dir, num_classes, device, infer_type):
    """
    Automates the testing process for a classification model.

    Args:
        model_path (str): Path to the trained model file.
        image_dir (str): Directory containing test images.
        num_classes (int): Number of classes in the classification problem.
        device (torch.device): Device to run the model on (CPU or GPU).
    """
    try:
        # Load the model
        model = torch.load(model_path, map_location=device)
        model.to(device)  # Memindahkan model ke device
        model.eval()

        # Initialize lists to store predictions and true labels
        predicted_labels = []
        true_labels = []

        # Iterate through the test images
        for cls in os.listdir(image_dir):
            cls_path = os.path.join(image_dir, cls)
            if not os.path.isdir(cls_path):
                continue
            for img in os.listdir(cls_path):
                image_path = os.path.join(cls_path, img)
                if image_path.endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                    predicted_label = infer(model, image_path, device, infer_type)
                    predicted_labels.append(predicted_label)
                    true_labels.append(int(cls))

        # Create the confusion matrix
        cm = confusion_matrix(true_labels, predicted_labels, labels=list(range(num_classes)))

        # Plot the confusion matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                    xticklabels=list(range(num_classes)),
                    yticklabels=list(range(num_classes)))
        plt.xlabel("Predicted Label")
        plt.ylabel("True Label")
        plt.title("Confusion Matrix")
        plt.show()

        # Compute and print metrics
        accuracy = accuracy_score(true_labels, predicted_labels)
        precision = precision_score(true_labels, predicted_labels, average='weighted')
        recall = recall_score(true_labels, predicted_labels, average='weighted')
        f1 = f1_score(true_labels, predicted_labels, average='weighted')

        print("Accuracy: {:.2f}%".format(accuracy * 100))
        print("Precision: {:.2f}%".format(precision * 100))
        print("Recall: {:.2f}%".format(recall * 100))
        print("F1 Score: {:.2f}%".format(f1 * 100))

        # Generate and print classification report
        target_names = [str(i) for i in range(num_classes)]
        print("\nClassification Report:")
        print(classification_report(true_labels, predicted_labels, target_names=target_names))

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example Usage
infer_type = 'warmup'

# Define model
if infer_type == 'warmup':
    model = fcn_resnet50(num_classes=3)
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/PH2_EWC_val/best.ptl'  # Warmup weight
else:
    from main.models import fcn_resnet50, fcn_3x64_gctx
    FT = torch.load('/workspace/yogiek/gc2/warmup/ckps/H-D/PH2_EWC_val/best.ptl', map_location='cpu')
    for parameter in FT.parameters():
        parameter.requires_grad = False
    model = {
        "FT": FT,
        "FS": fcn_resnet50(),
        "GS": fcn_3x64_gctx(),
    }
    weight_dir = '/workspace/yogiek/gc2/warmup/ckps/H-D/PH2_val/best-all.ptl'  # OOD weight

# Test dataset 4
image_dir = '/workspace/yogiek/gc2/datasets/H-D/test/4'  # Replace with your images directory
num_classes = 3  # Replace with the number of class in your model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Dataset 4")
automate_testing(weight_dir, image_dir, num_classes, device, infer_type)
# Out:
# Dataset 4
# Accuracy: 60.00%
# Precision: 60.82%
# Recall: 60.00%
# F1 Score: 58.72%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       0.55      0.75      0.63         8
#            2       0.75      0.75      0.75         4
#
#     accuracy                           0.60        20
#    macro avg       0.63      0.62      0.61        20
# weighted avg       0.61      0.60      0.59        20
